# %% [markdown]
# # test
#
# ---
#
# **Project**
# - <project-name>
#
# **Author**
# - 조동휘
#
# **Created**
# - 2026-03-06
#
# **Purpose**
# - nbqa pylint workflow test
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create simple dataset
data = np.arange(5)

df = pd.DataFrame({
    "value": data
})

print(df)
# Out:
#    value
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
# simple plot
plt.figure()
plt.plot(df["value"])
plt.title("nbqa lint test")
plt.show()
